# %% [markdown]
# # Solving MoCap Sequences
# It might be the case that you have an already labeled mocap dataset and you want to simply "mosh" it.
# Here we take
# [SOMA dataset's manually labeled mocaps](https://download.is.tue.mpg.de/download.php?domain=soma&sfile=evaluation_mocaps/original/SOMA_dataset/SOMA_manual_labeled.tar.bz2)
# as a sample case study and provide a code snippet to just mosh it.
# Please have in mind that we can also process your mocaps for you in case you agree to release them under
# [AMASS](https://amass.is.tue.mpg.de/)
# for research purposes.
#
# Furthermore, note that our goal is to simply mosh a dataset without considering comparability with other mosh runs;
# i.e. you cannot compare these results with SOMA experiments. For that refer to special mosh run presented in
# [here](run_soma_on_soma_dataset.ipynb).
#
# Finally, the same code can be used for rendering the MoSh results as well. Enjoy!

# %%
import os.path as osp
from glob import glob

import numpy as np
from loguru import logger

from soma.amass.mosh_manual import mosh_manual

# %%
soma_work_base_dir = '/home/nghorbani/Desktop/SOMA_Test'
support_base_dir = osp.join(soma_work_base_dir, 'support_files')

mocap_base_dir = osp.join(support_base_dir, 'evaluation_mocaps/original')

work_base_dir = osp.join(soma_work_base_dir, 'running_just_mosh')

target_ds_names = ['SOMA_manual_labeled',]

for ds_name in target_ds_names:
    mocap_fnames = glob(osp.join(mocap_base_dir, ds_name,  '*/*.c3d'))

    logger.info(f'#mocaps found for {ds_name}: {len(mocap_fnames)}')

    mosh_manual(
        mocap_fnames,
        mosh_cfg={
            'moshpp.verbosity': 1, # set to 2 to visulaize the process in meshviewer
            'dirs.work_base_dir': osp.join(work_base_dir, 'mosh_results'),
            'dirs.support_base_dir': support_base_dir,
        },
        render_cfg={
            'dirs.work_base_dir': osp.join(work_base_dir, 'mp4_renders'),
            'render.render_engine': 'eevee',  # eevee / cycles,
            # 'render.render_engine': 'cycles',  # eevee / cycles,
            'render.show_markers': True,
            # 'render.save_final_blend_file': True
            'dirs.support_base_dir': support_base_dir,

        },
        parallel_cfg={
            'pool_size': 1,
            'max_num_jobs': 1,
            'randomly_run_jobs': True,
        },
        run_tasks=[
            'mosh',
            # 'render',
        ],
        # fast_dev_run=True,
    )
# Out:
# 2021-10-09 20:05:05.410 | INFO     | __main__:<module>:12 - #mocaps found for SOMA_manual_labeled: 69
# 2021-10-09 20:05:08.191 | INFO     | soma.amass.mosh_manual:mosh_manual:107 - Submitting MoSh++ jobs.
# 2021-10-09 20:05:08.203 | INFO     | soma.tools.parallel_tools:run_parallel_jobs:54 - #Job(s) submitted: 2
# 2021-10-09 20:05:08.204 | INFO     | soma.tools.parallel_tools:run_parallel_jobs:58 - max_num_jobs is set to 1. choosing the first #Job(s): 1
# 2021-10-09 20:05:08.205 | INFO     | soma.tools.parallel_tools:run_parallel_jobs:67 - Will run the jobs in random order.
# soma_subject1 -- random_001 -- mosh_head:__init__:83 -- mocap_fname: /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/random_001.c3d
# soma_subject1 -- random_001 -- mosh_head:__init__:85 -- stagei_fname: /home/nghorbani/Desktop/SOMA_Test/running_just_mosh/mosh_results/SOMA_manual_labeled/soma_subject1/male_stagei.pkl
# soma_subject1 -- random_001 -- mosh_head:__init__:86 -- stageii_fname: /home/nghorbani/Desktop/SOMA_Test/running_just_mosh/mosh_results/SOMA_manual_labeled/soma_subject1/random_001_stageii.pkl
# soma_subject1 -- random_001 -- mosh_head:__init__:91 -- surface_model_type: smplx
# soma_subject1 -- random_001 -- mosh_head:__init__:92 -- gender: male
# soma_subject1 -- random_001 -- mosh_head:__init__:93 -- surface_model_fname: /home/nghorbani/Desktop/SOMA_Test/support_files/smplx/male/model.pkl
# soma_subject1 -- random_001 -- mosh_head:__init__:96 -- optimize_fingers: False, optimize_face: False, optimize_toes: False, optimize_betas: True, optimize_dynamics: False
# soma_subject1 -- random_001 -- mosh_head:prepare_stagei_frames:134 -- 12 subject specific mocap(s) are selected for mosh stagei.
# soma_subject1 -- random_001 -- mosh_head:prepare_stagei_frames:137 -- Selecting 12 frames using method random_strict on frames with 50% least_avail_markers
# soma_subject1 -- random_001 -- mosh_head:prepare_stagei_frames:171 -- Using frames for stage-i: ['/home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/random_003.c3d_000888'
#  '/home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/sit_003.c3d_001499'
#  '/home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/sit_003.c3d_002174'
#  '/home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/dance_001.c3d_001254'
#  '/home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/squat_002.c3d_000785'
#  '/home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/squat_001.c3d_000839'
#  '/home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/sit_003.c3d_000225'
#  '/home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/run_003.c3d_000525'
#  '/home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/squat_002.c3d_001996'
#  '/home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/dance_001.c3d_000726'
#  '/home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/kick_003.c3d_002125'
#  '/home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/SOMA_manual_labeled/soma_subject1/random_003.c3d_002278']
# soma_subject1 -- random_001 -- mosh_head:mosh_stagei:200 -- Marker layout not available. It will be produced ...
# soma_subject1 -- random_001 -- create_marker_layout_for_mocaps:marker_labels_to_marker_layout:66 -- Preparing marker layout for surface_model_type: smplx
# soma_subject1 -- random_001 -- create_marker_layout_for_mocaps:marker_labels_to_marker_layout:104 -- has_face: False, has_finger: False, has_body: True, wrist_markers_on_stick: False
# soma_subject1 -- random_001 -- create_marker_layout_for_mocaps:marker_labels_to_marker_layout:128 -- Created marker layout: /home/nghorbani/Desktop/SOMA_Test/running_just_mosh/mosh_results/SOMA_manual_labeled/SOMA_manual_labeled_smplx.json
# soma_subject1 -- random_001 -- mosh_head:mosh_stagei:210 -- Attempting mosh stagei to create /home/nghorbani/Desktop/SOMA_Test/running_just_mosh/mosh_results/SOMA_manual_labeled/soma_subject1/male_stagei.pkl
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:118 -- using marker_layout_fname: /home/nghorbani/Desktop/SOMA_Test/running_just_mosh/mosh_results/SOMA_manual_labeled/SOMA_manual_labeled_smplx.json
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:154 -- Estimating for #latent markers: 53
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:191 -- Number of  available markers in each stagei selected frames: (F00, 51), (F01, 53), (F02, 53), (F03, 53), (F04, 53), (F05, 53), (F06, 53), (F07, 53), (F08, 53), (F09, 53), (F10, 53), (F11, 51)
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:200 -- Rigidly aligning the body to the markers
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:224 -- MoSh stagei weights before annealing:
# stagei_wt_poseH: 3.0
# stagei_wt_poseF: 3.0
# stagei_wt_expr: 34.0
# stagei_wt_pose: 3.0
# stagei_wt_poseB: 3.0
# stagei_wt_init_finger_left: 400.0
# stagei_wt_init_finger_right: 400.0
# stagei_wt_betas: 10.0
# stagei_wt_init: 300
# stagei_wt_data: 75.0
# stagei_wt_surf: 10000.0
# stagei_wt_annealing: [1.0, 0.5, 0.25, 0.125]
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:228 -- head_marker_corr_fname is provided and is being loaded.
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:236 -- Taking into account the correlation of the head markers from head_marker_corr_fname = /home/nghorbani/Desktop/SOMA_Test/support_files/ssm_head_marker_corr.npz
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:242 -- Beginning mosh stagei with opt_settings.weights_type: smplx
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:307 -- Step 1/4 : Opt. wt_anneal_factor = 1.00, wt_data = 1.00, wt_poseB = 65.09
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:309 -- stagei_wt_init for different marker types body = 300.00:
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:311 -- stagei_wt_surf for different marker types body = 10000.00
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:363 -- Init. loss values: beta = 0.00e+00 | data = 8.68e+05 | init_body = 9.89e-27 | init_head_corr = 5.67e-28 | poseB = 2.46e+04 | surf_body = 5.01e+01
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:371 -- Final loss values: beta = 1.28e+02 | data = 4.78e+03 | init_body = 1.62e+03 | init_head_corr = 2.29e+01 | poseB = 1.16e+04 | surf_body = 1.15e+00
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:307 -- Step 2/4 : Opt. wt_anneal_factor = 0.50, wt_data = 0.50, wt_poseB = 130.19
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:309 -- stagei_wt_init for different marker types body = 150.00:
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:311 -- stagei_wt_surf for different marker types body = 10000.00
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:363 -- Init. loss values: beta = 3.21e+01 | data = 1.91e+04 | init_body = 4.06e+02 | init_head_corr = 5.73e+00 | poseB = 2.90e+03 | surf_body = 1.15e+00
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:371 -- Final loss values: beta = 1.60e+02 | data = 1.64e+03 | init_body = 2.86e+03 | init_head_corr = 6.99e+01 | poseB = 3.17e+03 | surf_body = 5.18e+00
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:307 -- Step 3/4 : Opt. wt_anneal_factor = 0.25, wt_data = 0.25, wt_poseB = 260.38
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:309 -- stagei_wt_init for different marker types body = 75.00:
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:311 -- stagei_wt_surf for different marker types body = 10000.00
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:363 -- Init. loss values: beta = 4.00e+01 | data = 6.55e+03 | init_body = 7.14e+02 | init_head_corr = 1.75e+01 | poseB = 7.93e+02 | surf_body = 5.18e+00
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:371 -- Final loss values: beta = 2.81e+02 | data = 2.89e+03 | init_body = 9.07e+02 | init_head_corr = 6.36e+01 | poseB = 9.66e+02 | surf_body = 1.03e+02
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:307 -- Step 4/4 : Opt. wt_anneal_factor = 0.12, wt_data = 0.12, wt_poseB = 520.75
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:309 -- stagei_wt_init for different marker types body = 37.50:
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:311 -- stagei_wt_surf for different marker types body = 10000.00
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:363 -- Init. loss values: beta = 7.02e+01 | data = 1.16e+04 | init_body = 2.27e+02 | init_head_corr = 1.59e+01 | poseB = 2.41e+02 | surf_body = 1.03e+02
# soma_subject1 -- random_001 -- chmosh:mosh_stagei:371 -- Final loss values: beta = 1.16e+02 | data = 9.81e+03 | init_body = 2.35e+02 | init_head_corr = 2.42e+01 | poseB = 2.66e+02 | surf_body = 5.18e+01
# soma_subject1 -- random_001 -- mosh_head:mosh_stagei:226 -- created stagei_fname: /home/nghorbani/Desktop/SOMA_Test/running_just_mosh/mosh_results/SOMA_manual_labeled/soma_subject1/male_stagei.pkl
# soma_subject1 -- random_001 -- mosh_head:mosh_stagei:228 -- finished mosh stagei in 0:29:26.322608
# soma_subject1 -- random_001 -- mosh_head:run_moshpp_once:408 -- Final mosh stagei loss: data = 9.63e+07 | poseB = 7.06e+04 | init_body = 5.53e+04 | init_head_corr = 5.83e+02 | beta = 1.34e+04 | surf_body = 2.69e+03
# soma_subject1 -- random_001 -- mosh_head:mosh_stageii:242 -- attempting mosh stageii to create /home/nghorbani/Desktop/SOMA_Test/running_just_mosh/mosh_results/SOMA_manual_labeled/soma_subject1/random_001_stageii.pkl
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:424 -- Loaded mocap markers for mosh stageii
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:443 -- #observed, #simulated markers: 53, 53
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:468 -- mosh stageii weights are subject to change during the optimization, depending on how many markers are absent in each frame.
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:472 -- MoSh stagei weights before annealing:
# stageii_wt_data: 400
# stageii_wt_velo: 2.5
# stageii_wt_dmpl: 1.0
# stageii_wt_expr: 1.0
# stageii_wt_poseB: 1.6
# stageii_wt_poseH: 1.0
# stageii_wt_poseF: 1.0
# stageii_wt_annealing: 2.5
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:476 -- Starting mosh stageii for 2541 frames.
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:552 -- Rigidly aligning the markers to the body...
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0000/2541 -- Step 1. initial loss values: data = 1.38e+02 | poseB = 2.69e+02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0000/2541 -- Step 1. final loss values: data = 1.38e+02 | poseB = 2.70e+02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0000/2541 -- Step 2. initial loss values: data = 1.38e+02 | poseB = 2.70e+02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0000/2541 -- Step 2. final loss values: data = 1.38e+02 | poseB = 2.70e+02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0001/2541 -- Step 1. initial loss values: data = 1.38e+02 | poseB = 2.70e+02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0001/2541 -- Step 1. final loss values: data = 1.38e+02 | poseB = 2.70e+02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0001/2541 -- Step 2. initial loss values: data = 1.38e+02 | poseB = 2.70e+02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0001/2541 -- Step 2. final loss values: data = 1.38e+02 | poseB = 2.70e+02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0002/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 4.56e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0002/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 9.41e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0002/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 9.41e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0002/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 9.04e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0003/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.42e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0003/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.86e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0003/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.86e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0003/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.86e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0004/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.18e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0004/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.56e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0004/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.56e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0004/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.89e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0005/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.15e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0005/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.05e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0005/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.05e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0005/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.05e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0006/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.80e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0006/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.24e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0006/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.24e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0006/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 6.67e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0007/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.64e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0007/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.29e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0007/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.29e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0007/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.29e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0008/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.73e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0008/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 6.65e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0008/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 6.65e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0008/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.83e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0009/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.94e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0009/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.72e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0009/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.72e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0009/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.14e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0010/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.24e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0010/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.96e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0010/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.96e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0010/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.73e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0011/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.13e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0011/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.41e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0011/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.41e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0011/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.27e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0012/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.63e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0012/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 4.06e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0012/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 4.06e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0012/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.66e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0013/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.26e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0013/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.39e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0013/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.39e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0013/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.61e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0014/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.86e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0014/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.17e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0014/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.17e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0014/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.17e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0015/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.55e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0015/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.44e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0015/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.44e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0015/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.44e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0016/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.92e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0016/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 6.66e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0016/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 6.66e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0016/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 6.66e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0017/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.71e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0017/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.55e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0017/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.55e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0017/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.55e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0018/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.06e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0018/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.05e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0018/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.05e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0018/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.05e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0019/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 1.52e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0019/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.27e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0019/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.27e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0019/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.27e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0020/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 1.30e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0020/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.57e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0020/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.57e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0020/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.57e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0021/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 1.44e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0021/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.57e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0021/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.57e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0021/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.57e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0022/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 1.57e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0022/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.98e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0022/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.98e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0022/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.98e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0023/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.38e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0023/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.35e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0023/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.35e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0023/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.35e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0024/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.38e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0024/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.80e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0024/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.80e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0024/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.80e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0025/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 1.85e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0025/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.28e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0025/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.28e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0025/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.28e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0026/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 1.74e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0026/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.94e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0026/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.94e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0026/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.94e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0027/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 1.78e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0027/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 9.62e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0027/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 9.62e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0027/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 1.00e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0028/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.30e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0028/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 6.52e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0028/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 6.52e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0028/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 6.50e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0029/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.40e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0029/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.64e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0029/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.64e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0029/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.73e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0030/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.76e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0030/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.03e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0030/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.03e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0030/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.94e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0031/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.43e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0031/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.40e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0031/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.40e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0031/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.69e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0032/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.74e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0032/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.74e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0032/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.74e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0032/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.54e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0033/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.77e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0033/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.24e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0033/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.24e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0033/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.24e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0034/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.22e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0034/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.16e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0034/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.16e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0034/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.16e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0035/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.64e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0035/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.45e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0035/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.45e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0035/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.45e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0036/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.77e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0036/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.00e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0036/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.00e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0036/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.00e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0037/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.00e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0037/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.33e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0037/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.33e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0037/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.33e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0038/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.03e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0038/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 6.21e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0038/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 6.21e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0038/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 6.73e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0039/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.52e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0039/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.15e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0039/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 5.15e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0039/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.28e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0040/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.65e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0040/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 1.81e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0040/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 1.81e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0040/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 1.94e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0041/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.46e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0041/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.74e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0041/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.74e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0041/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.79e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0042/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.05e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0042/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.42e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0042/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.42e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0042/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.42e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0043/2541 -- Step 1. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 1.84e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0043/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.04e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0043/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.04e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0043/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 2.36e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0044/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.77e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0044/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.28e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0044/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.28e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0044/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 4.12e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0045/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.09e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0045/2541 -- Step 1. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.22e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0045/2541 -- Step 2. initial loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.22e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0045/2541 -- Step 2. final loss values: data = 1.36e+02 | poseB = 2.70e+02 | velo = 3.29e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0046/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.93e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0046/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.87e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0046/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.87e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0046/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.83e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0047/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.65e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0047/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.00e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0047/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.00e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0047/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.92e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0048/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.77e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0048/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 4.26e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0048/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 4.26e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0048/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.83e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0049/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.79e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0049/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.41e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0049/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.41e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0049/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.12e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0050/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.81e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0050/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 4.24e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0050/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 4.24e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0050/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.06e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0051/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.52e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0051/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.56e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0051/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.56e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0051/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.35e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0052/2541 -- Step 1. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 1.56e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0052/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.38e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0052/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.38e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0052/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 3.63e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0053/2541 -- Step 1. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 1.73e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0053/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.67e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0053/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.67e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0053/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 4.96e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0054/2541 -- Step 1. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 1.58e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0054/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.22e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0054/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.22e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0054/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 2.09e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0055/2541 -- Step 1. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 1.70e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0055/2541 -- Step 1. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.88e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0055/2541 -- Step 2. initial loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.88e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0055/2541 -- Step 2. final loss values: data = 1.37e+02 | poseB = 2.70e+02 | velo = 5.93e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0056/2541 -- Step 1. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 2.09e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0056/2541 -- Step 1. final loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 5.52e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0056/2541 -- Step 2. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 5.52e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0056/2541 -- Step 2. final loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 5.65e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0057/2541 -- Step 1. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 1.91e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0057/2541 -- Step 1. final loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 4.67e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0057/2541 -- Step 2. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 4.67e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0057/2541 -- Step 2. final loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 4.97e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0058/2541 -- Step 1. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 2.41e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0058/2541 -- Step 1. final loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 2.14e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0058/2541 -- Step 2. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 2.14e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0058/2541 -- Step 2. final loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 2.36e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0059/2541 -- Step 1. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 2.58e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0059/2541 -- Step 1. final loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 3.14e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0059/2541 -- Step 2. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 3.14e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0059/2541 -- Step 2. final loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 4.45e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0060/2541 -- Step 1. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 3.07e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0060/2541 -- Step 1. final loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 6.42e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0060/2541 -- Step 2. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 6.42e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0060/2541 -- Step 2. final loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 6.94e-07
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0061/2541 -- Step 1. initial loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 3.46e-06
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0061/2541 -- Step 1. final loss values: data = 1.38e+02 | poseB = 2.70e+02 | velo = 4.59e-07
# ...
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0341/2541 -- Step 2. final loss values: data = 2.20e+02 | poseB = 3.02e+02 | velo = 1.49e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0342/2541 -- Step 1. initial loss values: data = 2.47e+03 | poseB = 3.02e+02 | velo = 7.03e-02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0342/2541 -- Step 1. final loss values: data = 2.11e+02 | poseB = 3.02e+02 | velo = 1.46e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0342/2541 -- Step 2. initial loss values: data = 2.11e+02 | poseB = 3.02e+02 | velo = 1.46e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0342/2541 -- Step 2. final loss values: data = 2.10e+02 | poseB = 3.02e+02 | velo = 1.26e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0343/2541 -- Step 1. initial loss values: data = 2.51e+03 | poseB = 3.02e+02 | velo = 6.15e-02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0343/2541 -- Step 1. final loss values: data = 2.07e+02 | poseB = 3.03e+02 | velo = 1.32e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0343/2541 -- Step 2. initial loss values: data = 2.07e+02 | poseB = 3.03e+02 | velo = 1.32e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0343/2541 -- Step 2. final loss values: data = 2.07e+02 | poseB = 3.03e+02 | velo = 1.27e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0344/2541 -- Step 1. initial loss values: data = 2.56e+03 | poseB = 3.03e+02 | velo = 5.46e-02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0344/2541 -- Step 1. final loss values: data = 2.09e+02 | poseB = 3.05e+02 | velo = 1.39e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0344/2541 -- Step 2. initial loss values: data = 2.09e+02 | poseB = 3.05e+02 | velo = 1.39e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0344/2541 -- Step 2. final loss values: data = 2.09e+02 | poseB = 3.05e+02 | velo = 1.51e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0345/2541 -- Step 1. initial loss values: data = 2.62e+03 | poseB = 3.05e+02 | velo = 4.96e-02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0345/2541 -- Step 1. final loss values: data = 2.14e+02 | poseB = 3.06e+02 | velo = 1.18e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0345/2541 -- Step 2. initial loss values: data = 2.14e+02 | poseB = 3.06e+02 | velo = 1.18e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0345/2541 -- Step 2. final loss values: data = 2.14e+02 | poseB = 3.06e+02 | velo = 1.29e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0346/2541 -- Step 1. initial loss values: data = 2.68e+03 | poseB = 3.06e+02 | velo = 4.77e-02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0346/2541 -- Step 1. final loss values: data = 2.24e+02 | poseB = 3.08e+02 | velo = 1.27e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0346/2541 -- Step 2. initial loss values: data = 2.24e+02 | poseB = 3.08e+02 | velo = 1.27e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0346/2541 -- Step 2. final loss values: data = 2.24e+02 | poseB = 3.08e+02 | velo = 1.18e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0347/2541 -- Step 1. initial loss values: data = 2.75e+03 | poseB = 3.08e+02 | velo = 4.58e-02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0347/2541 -- Step 1. final loss values: data = 2.37e+02 | poseB = 3.09e+02 | velo = 1.05e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0347/2541 -- Step 2. initial loss values: data = 2.37e+02 | poseB = 3.09e+02 | velo = 1.05e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0347/2541 -- Step 2. final loss values: data = 2.37e+02 | poseB = 3.09e+02 | velo = 1.14e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0348/2541 -- Step 1. initial loss values: data = 2.82e+03 | poseB = 3.09e+02 | velo = 4.68e-02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0348/2541 -- Step 1. final loss values: data = 2.49e+02 | poseB = 3.11e+02 | velo = 8.70e-04
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0348/2541 -- Step 2. initial loss values: data = 2.49e+02 | poseB = 3.11e+02 | velo = 8.70e-04
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0348/2541 -- Step 2. final loss values: data = 2.49e+02 | poseB = 3.11e+02 | velo = 8.60e-04
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0349/2541 -- Step 1. initial loss values: data = 2.89e+03 | poseB = 3.11e+02 | velo = 4.87e-02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0349/2541 -- Step 1. final loss values: data = 2.57e+02 | poseB = 3.12e+02 | velo = 8.26e-04
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0349/2541 -- Step 2. initial loss values: data = 2.57e+02 | poseB = 3.12e+02 | velo = 8.26e-04
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0349/2541 -- Step 2. final loss values: data = 2.57e+02 | poseB = 3.12e+02 | velo = 8.28e-04
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0350/2541 -- Step 1. initial loss values: data = 2.94e+03 | poseB = 3.12e+02 | velo = 4.81e-02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0350/2541 -- Step 1. final loss values: data = 2.60e+02 | poseB = 3.14e+02 | velo = 1.15e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0350/2541 -- Step 2. initial loss values: data = 2.60e+02 | poseB = 3.14e+02 | velo = 1.15e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0350/2541 -- Step 2. final loss values: data = 2.60e+02 | poseB = 3.14e+02 | velo = 1.15e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0351/2541 -- Step 1. initial loss values: data = 2.99e+03 | poseB = 3.14e+02 | velo = 4.65e-02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0351/2541 -- Step 1. final loss values: data = 2.60e+02 | poseB = 3.15e+02 | velo = 1.24e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0351/2541 -- Step 2. initial loss values: data = 2.60e+02 | poseB = 3.15e+02 | velo = 1.24e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0351/2541 -- Step 2. final loss values: data = 2.60e+02 | poseB = 3.15e+02 | velo = 1.24e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0352/2541 -- Step 1. initial loss values: data = 3.03e+03 | poseB = 3.15e+02 | velo = 4.63e-02
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:590 -- 0352/2541 -- Step 1. final loss values: data = 2.56e+02 | poseB = 3.16e+02 | velo = 1.01e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:616 -- 0352/2541 -- Step 2. initial loss values: data = 2.56e+02 | poseB = 3.16e+02 | velo = 1.01e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:621 -- 0352/2541 -- Step 2. final loss values: data = 2.56e+02 | poseB = 3.16e+02 | velo = 1.01e-03
# soma_subject1 -- random_001 -- chmosh:mosh_stageii:580 -- 0353/2541 -- Step 1. initial loss values: data = 3.05e+03 | poseB = 3.16e+02 | velo = 4.55e-02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1958128/2261270818.py in <module>
#      34         },
#      35         run_tasks=[
# ---> 36             'mosh',
#      37             # 'render',
#      38         ],
#
# /is/ps3/nghorbani/code-repos/soma_public/src/soma/amass/mosh_manual.py in mosh_manual(mocap_fnames, mosh_cfg, render_cfg, parallel_cfg, **kwargs)
#     109         base_parallel_cfg = OmegaConf.load(osp.join(app_support_dir, 'conf/parallel_conf/moshpp_parallel.yaml'))
#     110         moshpp_parallel_cfg = OmegaConf.merge(base_parallel_cfg, OmegaConf.create(parallel_cfg))
# --> 111         run_parallel_jobs(func=run_moshpp_once, jobs=mosh_jobs, parallel_cfg=moshpp_parallel_cfg)
#     112
#     113     if 'render' in run_tasks:
#
# /is/ps3/nghorbani/code-repos/soma_public/src/soma/tools/parallel_tools.py in run_parallel_jobs(func, jobs, parallel_cfg, base_parallel_cfg)
#      77     else:
#      78         for job in jobs:
# ---> 79             func(job)
#      80             # print(job)
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/moshpp-3.0-py3.7.egg/moshpp/mosh_head.py in run_moshpp_once(cfg)
#     408         [f'{k} = {np.sum(v ** 2):2.2e}' for k, v in mp.stagei_data['stagei_debug_details']['stagei_errs'].items()])))
#     409
# --> 410     mp.mosh_stageii(mosh_stageii)
#     411     logger.debug('Final mosh stageii loss: {}'.format(' | '.join(
#     412         [f'{k} = {np.sum(v ** 2):2.2e}' for k, v in
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/moshpp-3.0-py3.7.egg/moshpp/mosh_head.py in mosh_stageii(self, mosh_stageii_func)
#     249                                              betas=self.stagei_data['betas'],
#     250                                              marker_meta=self.stagei_data['marker_meta'],
# --> 251                                              v_template_fname=self.stagei_data.get('v_template_fname'))
#     252             stageii_elapsed_time = time.time() - tm
#     253
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/moshpp-3.0-py3.7.egg/moshpp/chmosh.py in mosh_stageii(mocap_fname, cfg, markers_latent, latent_labels, betas, marker_meta, v_template_fname)
#     586         ch.minimize(fun=list(opt_objs.values()) if cfg.moshpp.verbosity == 0 else opt_objs, x0=free_vars,
#     587                     method='dogleg',
# --> 588                     options={'e_3': .01, 'delta_0': 5e-1, 'disp': None, 'maxiter': cfg.opt_settings.maxiter})
#     589         logger.debug(
#     590             f'{fIdx:04d}/{len(selected_frames):04d} -- Step 1. final loss values: {" | ".join(["{} = {:2.2e}".format(k, np.sum(v.r ** 2)) for k, v in opt_objs.items()])}')
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/optimization.py in minimize(fun, x0, method, bounds, constraints, tol, callback, options)
#      39     if method == 'dogleg':
#      40         if options is None: options = {}
# ---> 41         return minimize_dogleg(fun, free_variables=x0, on_step=callback, **options)
#      42
#      43     if isinstance(fun, list) or isinstance(fun, tuple):
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/optimization_internal.py in minimize_dogleg(obj, free_variables, on_step, maxiter, max_fevals, sparse_solver, disp, e_1, e_2, e_3, delta_0, treat_as_dense)
#     436                         stop('stopping because improvement < %.1e%%' % (100*e_3))
#     437                     else:
# --> 438                         state.updateJ(obj)
#     439                         state.r = trial.r
#     440                         if np.linalg.norm(state.g, np.inf) < e_1:
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/optimization_internal.py in updateJ(self, obj)
#     302         tm = timer()
#     303         pif('computing Jacobian...')
# --> 304         self.J = obj.J
#     305         if self.J is None:
#     306             raise Exception("Computing Jacobian failed!")
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/optimization_internal.py in J(self)
#     103         Compute Jacobian. Analyze dr graph first to disable unnecessary caching
#     104         '''
# --> 105         result = self.dr_wrt(self.x, profiler=self.profiler).copy()
#     106         if self.profiler:
#     107             self.profiler.harvest()
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/optimization_internal.py in dr_wrt(self, wrt, profiler)
#      41                 tm = timer()
#      42                 if isinstance(freevar, ch.Select):
# ---> 43                     new_jac = self.obj.dr_wrt(freevar.a, profiler=profiler)
#      44                     try:
#      45                         new_jac = new_jac[:, freevar.idxs]
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/ch.py in dr_wrt(self, wrt, reverse_mode, profiler)
#     770                 else: # forward mode
#     771                     tm_dr_wrt.pause()
# --> 772                     dr2 = p.dr_wrt(wrt, profiler=profiler)
#     773                     tm_dr_wrt.resume()
#     774                     if dr2 is not None:
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/ch.py in dr_wrt(self, wrt, reverse_mode, profiler)
#     770                 else: # forward mode
#     771                     tm_dr_wrt.pause()
# --> 772                     dr2 = p.dr_wrt(wrt, profiler=profiler)
#     773                     tm_dr_wrt.resume()
#     774                     if dr2 is not None:
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/ch.py in dr_wrt(self, wrt, reverse_mode, profiler)
#     770                 else: # forward mode
#     771                     tm_dr_wrt.pause()
# --> 772                     dr2 = p.dr_wrt(wrt, profiler=profiler)
#     773                     tm_dr_wrt.resume()
#     774                     if dr2 is not None:
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/ch.py in dr_wrt(self, wrt, reverse_mode, profiler)
#     770                 else: # forward mode
#     771                     tm_dr_wrt.pause()
# --> 772                     dr2 = p.dr_wrt(wrt, profiler=profiler)
#     773                     tm_dr_wrt.resume()
#     774                     if dr2 is not None:
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/ch.py in dr_wrt(self, wrt, reverse_mode, profiler)
#     773                     tm_dr_wrt.resume()
#     774                     if dr2 is not None:
# --> 775                         indirect_dr = self.compute_rop(p, rhs=dr2)
#     776
#     777                 if indirect_dr is not None:
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/ch.py in compute_rop(self, wrt, rhs)
#     722
#     723     def compute_rop(self, wrt, rhs):
# --> 724         dr = self._compute_dr_wrt_sliced(wrt)
#     725         if dr is None: return None
#     726
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/ch.py in _compute_dr_wrt_sliced(self, wrt)
#     287         #     return np.array([[1]])
#     288
# --> 289         result = self.compute_dr_wrt(wrt)
#     290         if result is not None:
#     291             return result
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/chumpy/reordering.py in compute_dr_wrt(self, wrt)
#     411         data = np.concatenate(data)
#     412
# --> 413         res = sp.csc_matrix((data, (IS, JS)), shape=(self.r.size, wrt.size))
#     414
#     415         if len(list(self._parents.keys())) != 1:
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/scipy/sparse/compressed.py in __init__(self, arg1, shape, dtype, copy)
#      53                     from .coo import coo_matrix
#      54                     other = self.__class__(coo_matrix(arg1, shape=shape,
# ---> 55                                                       dtype=dtype))
#      56                     self._set_self(other)
#      57                 elif len(arg1) == 3:
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/scipy/sparse/coo.py in __init__(self, arg1, shape, dtype, copy)
#     194             self.data = self.data.astype(dtype, copy=False)
#     195
# --> 196         self._check()
#     197
#     198     def reshape(self, *args, **kwargs):
#
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/scipy/sparse/coo.py in _check(self)
#     280
#     281         if self.nnz > 0:
# --> 282             if self.row.max() >= self.shape[0]:
#     283                 raise ValueError('row index exceeds matrix dimensions')
#     284             if self.col.max() >= self.shape[1]:
#
# KeyboardInterrupt:

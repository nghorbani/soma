# %% [markdown]
# ## Ablation Expriments
#
# We ran various ablative studies in the [SOMA paper](https://download.is.tue.mpg.de/soma/SOMA_ICCV19.pdf)
# and here we show how we had the control on training and runtime settings.
#
# Furthermore, we show how to prepare mocap sequences with controllable noise that we use for evaluation purposes.
#
# We assume you have already gone through the  [Running SOMA on SOMA dataset](src/tutorials/runing_soma_on_soma_dataset.ipynb) tutorial and
# that you have the required folder structure in place.
#
# ## Preparing MoCap Data With Controlled Noise
#
# In the SOMA paper, we use [HDM05](http://resources.mpi-inf.mpg.de/HDM05/) for validation purposes.
# This dataset is separating from actual test datasets, i.e. BMLmovi, BMLrub, KIT, and SOMA Dataset,
# to avoid probable overfitting to a certain test dataset.
# We use choose
# [215 sequences across 4 subjects](https://download.is.tue.mpg.de/soma/tutorials/validation_hdm05_sequences.txt).
# First download the
# [HDM05 folder structure](https://download.is.tue.mpg.de/download.php?domain=soma&sfile=evaluation_mocaps/original/HDM05.tar.bz2)
# and uncompress it under
# ```` support_files/evaluation_mocaps/original ````
# as we created the root directories in [Running SOMA on SOMA dataset](src/tutorials/runing_soma_on_soma_dataset.ipynb) tutorial.
#
# Afterward download [these sequences](https://download.is.tue.mpg.de/soma/tutorials/validation_hdm05_sequences.txt) from the
# [HDM05 project website](http://resources.mpi-inf.mpg.de/HDM05/)
# and
# place them in their appropriate folders.
#
# Download the
# [HDM05 markerlayout](https://download.is.tue.mpg.de/download.php?domain=soma&sfile=smplx/marker_layouts/HDM05.tar.bz2)
# and place it under
# ```` support_files/marker_layouts ````.
#
# We can corrupt a given clean mocap sequence with various noise types including, marker occlusion, ghost points, and broken trajectories.
# For this we use the function *def inject_synthetic_noise_into_real_mocap* and below we demonstrate an example application
# on HDM05 sequences that we just prepared.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
# %matplotlib inline

# %%
import os.path as osp
from glob import glob

from soma.data.corrupt_real_mocap_markers import inject_synthetic_noise_into_real_mocap

soma_work_base_dir = '/home/nghorbani/Desktop/SOMA_Test'
support_base_dir = osp.join(soma_work_base_dir, 'support_files')

mocap_dir = osp.join(support_base_dir, 'evaluation_mocaps/original')
mocap_out_base_dir = osp.join(support_base_dir, 'evaluation_mocaps/with_synthetic_noise')

hdm05_marker_layout_fname = osp.join(support_base_dir, 'marker_layouts/HDM05/dg/HDM_dg_01-04_01_120_smplx_finetuned.json')
assert osp.exists(hdm05_marker_layout_fname)

# %%
mocap_fnames = glob(osp.join(mocap_dir, 'HDM05', '*/*.c3d'))

args = {
    'marker_layout_fnames': {
        'HDM05': hdm05_marker_layout_fname},
    'dataset_mocap_fnames': {'HDM05': mocap_fnames},
    'oc_g_bt_settings': [(5, 3, 0), (5, 3, 50)], # (# occlusions, # ghost points, # broken trajectories)
    'mocap_unit': 'mm',
    'use_exact_num_oc': False,
    'mocap_rotate': None,
    'fname_filter': ['*bk/*', '*dg/*', '*mm/*', '*tr/*'], #can also be commented out
    'mocap_out_base_dir': mocap_out_base_dir,
}

inject_synthetic_noise_into_real_mocap(**args)
# Out:
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:105 -- #215 source mocaps found for HDM05
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-01_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.91%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-01_01_120.pkl, [torch.Size([10283, 43, 3])]
# /is/ps3/nghorbani/code-repos/soma_public/src/soma/data/corrupt_real_mocap_markers.py:171: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:30.)
#   label_ids[nan_mask] = nan_class_id
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-01_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.89%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-01_02_120.pkl, [torch.Size([8747, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-01_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.00%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.90%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-01_03_120.pkl, [torch.Size([8969, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-02_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.97%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.93%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-02_01_120.pkl, [torch.Size([3421, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-02_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.23%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.07%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-02_02_120.pkl, [torch.Size([2834, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-02_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.23%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.97%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-02_03_120.pkl, [torch.Size([3406, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-03_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.05%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.91%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-03_01_120.pkl, [torch.Size([6707, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-03_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.04%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.89%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-03_02_120.pkl, [torch.Size([6211, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-03_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.99%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.92%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-03_03_120.pkl, [torch.Size([5115, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-03_04_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.07%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.88%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-03_04_120.pkl, [torch.Size([4562, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-03_05_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.07%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.92%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-03_05_120.pkl, [torch.Size([4467, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-04_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.11%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-04_01_120.pkl, [torch.Size([7677, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-04_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.03%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.89%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-04_02_120.pkl, [torch.Size([7752, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_01-04_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.98%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.90%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_01-04_03_120.pkl, [torch.Size([6722, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_02-01_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.26%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.15%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_02-01_01_120.pkl, [torch.Size([3645, 41, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_02-01_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.13%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.99%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_02-01_02_120.pkl, [torch.Size([3714, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_02-01_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.18%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.00%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_02-01_03_120.pkl, [torch.Size([3304, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_02-02_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.13%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.04%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_02-02_01_120.pkl, [torch.Size([6680, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_02-02_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.08%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.00%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_02-02_02_120.pkl, [torch.Size([7095, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_02-02_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.12%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.03%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_02-02_03_120.pkl, [torch.Size([6449, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_02-03_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.27%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.99%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_02-03_01_120.pkl, [torch.Size([2530, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_02-03_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.14%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.04%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_02-03_02_120.pkl, [torch.Size([1867, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_02-03_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.06%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.96%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_02-03_03_120.pkl, [torch.Size([2143, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_02-03_04_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.17%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.09%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_02-03_04_120.pkl, [torch.Size([1915, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-02_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.08%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.00%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-02_01_120.pkl, [torch.Size([4981, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-02_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.17%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.04%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-02_02_120.pkl, [torch.Size([4141, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-02_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.09%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.03%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-02_03_120.pkl, [torch.Size([4269, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-03_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.14%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.00%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-03_01_120.pkl, [torch.Size([4412, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-03_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.22%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.14%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-03_02_120.pkl, [torch.Size([5018, 41, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-03_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.21%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.14%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-03_03_120.pkl, [torch.Size([4789, 41, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-04_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.08%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.02%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-04_01_120.pkl, [torch.Size([11399, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-04_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.07%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-04_02_120.pkl, [torch.Size([7422, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-04_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.05%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.02%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-04_03_120.pkl, [torch.Size([7828, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-04_04_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.04%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.88%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-04_04_120.pkl, [torch.Size([7330, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-05_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.06%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.00%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-05_01_120.pkl, [torch.Size([6041, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-05_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.09%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.04%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-05_02_120.pkl, [torch.Size([4639, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-05_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.17%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.04%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-05_03_120.pkl, [torch.Size([4612, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-11_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.00%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-11_01_120.pkl, [torch.Size([3113, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-11_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.06%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.99%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-11_02_120.pkl, [torch.Size([3277, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_03-11_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.15%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_03-11_03_120.pkl, [torch.Size([3008, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_04-01_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.15%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.02%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_04-01_01_120.pkl, [torch.Size([13319, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_04-01_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.31%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.13%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_04-01_02_120.pkl, [torch.Size([12530, 41, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_04-01_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.30%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.18%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_04-01_03_120.pkl, [torch.Size([12640, 41, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_05-01_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.97%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.93%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_05-01_01_120.pkl, [torch.Size([5544, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_05-01_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.10%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.00%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_05-01_02_120.pkl, [torch.Size([6154, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_05-01_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.94%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_05-01_03_120.pkl, [torch.Size([5841, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_05-02_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.18%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.02%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_05-02_01_120.pkl, [torch.Size([4192, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_05-02_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.19%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_05-02_02_120.pkl, [torch.Size([4386, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_05-02_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.20%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.03%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_05-02_03_120.pkl, [torch.Size([4163, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_05-03_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.08%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.04%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_05-03_01_120.pkl, [torch.Size([4128, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_05-03_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.16%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.00%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_05-03_02_120.pkl, [torch.Size([4594, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/bk/HDM_bk_05-03_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.09%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.07%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/bk/HDM_bk_05-03_03_120.pkl, [torch.Size([3909, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-01_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.20%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.03%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-01_01_120.pkl, [torch.Size([7542, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-01_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.14%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.04%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-01_02_120.pkl, [torch.Size([7660, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-01_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.10%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.05%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-01_03_120.pkl, [torch.Size([7687, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-01_04_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.11%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-01_04_120.pkl, [torch.Size([7647, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-02_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.12%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.10%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-02_01_120.pkl, [torch.Size([2867, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-02_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.94%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.90%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-02_02_120.pkl, [torch.Size([2762, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-02_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.06%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.92%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-02_03_120.pkl, [torch.Size([2786, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-03_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.03%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.96%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-03_01_120.pkl, [torch.Size([3498, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-03_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.06%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.94%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-03_02_120.pkl, [torch.Size([3794, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-03_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.11%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.06%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-03_03_120.pkl, [torch.Size([3584, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-04_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.94%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.90%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-04_01_120.pkl, [torch.Size([5509, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-04_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.05%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.03%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-04_02_120.pkl, [torch.Size([6394, 42, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_01-04_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.96%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.90%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_01-04_03_120.pkl, [torch.Size([6047, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_02-01_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.96%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.88%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_02-01_02_120.pkl, [torch.Size([3526, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_02-01_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.96%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.92%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_02-01_03_120.pkl, [torch.Size([3108, 43, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/dg/HDM_dg_02-02_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.04%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.90%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/dg/HDM_dg_02-02_01_120.pkl, [torch.Size([6087, 43, 3])]
# ...
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.03%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.89%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_03-04_01_120.pkl, [torch.Size([6239, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_03-04_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.03%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.86%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_03-04_02_120.pkl, [torch.Size([6988, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_03-04_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.07%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.92%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_03-04_03_120.pkl, [torch.Size([7553, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_03-05_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.07%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.92%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_03-05_01_120.pkl, [torch.Size([4999, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_03-05_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.03%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.89%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_03-05_02_120.pkl, [torch.Size([4500, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_03-05_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.07%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.87%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_03-05_03_120.pkl, [torch.Size([4357, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_03-10_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.82%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_03-10_02_120.pkl, [torch.Size([2479, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_03-10_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.97%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.94%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_03-10_03_120.pkl, [torch.Size([1578, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_03-11_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.09%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.95%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_03-11_01_120.pkl, [torch.Size([3635, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_03-11_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.95%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_03-11_02_120.pkl, [torch.Size([2581, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_03-11_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.93%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.88%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_03-11_03_120.pkl, [torch.Size([2209, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_04-01_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.16%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_04-01_01_120.pkl, [torch.Size([11202, 92, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_05-01_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.03%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.89%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_05-01_02_120.pkl, [torch.Size([4942, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_05-01_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.90%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_05-01_03_120.pkl, [torch.Size([4316, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_05-02_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.07%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.81%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_05-02_01_120.pkl, [torch.Size([1691, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_05-02_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.99%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.87%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_05-02_02_120.pkl, [torch.Size([1726, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_05-02_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 4.89%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.95%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_05-02_03_120.pkl, [torch.Size([1705, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_05-03_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.11%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.85%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_05-03_01_120.pkl, [torch.Size([3224, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_05-03_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.00%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.94%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_05-03_02_120.pkl, [torch.Size([3634, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_05-03_03_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.10%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.97%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_05-03_03_120.pkl, [torch.Size([3338, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_05-03_04_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.01%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.92%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_05-03_04_120.pkl, [torch.Size([6453, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_06-01_01_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.00%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 4.91%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_06-01_01_120.pkl, [torch.Size([10768, 93, 3])]
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:117 -- Starting to process /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/original/HDM05/tr/HDM_tr_06-01_02_120.c3d
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:155 -- Original occ rate 0.00% and with synthetic occlusion 5.09%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:168 -- Average per-frame ghost rate: 5.03%
# corrupt_real_mocap_markers:inject_synthetic_noise_into_real_mocap:191 -- Created /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_50/tr/HDM_tr_06-01_02_120.pkl, [torch.Size([16137, 92, 3])]

# %% [markdown]
# Here we produced two sets of corrupted mocap datasets for validation; i.e. *(5, 3, 0) and (5, 3, 50)*.
# The first one does not have broken trajectories, while the latter has up-tp 50 broken point trajectories.
# We use the former for per-frame metrics and the latter for tracklet labeling mode.
# All ablative experiments in SOMA paper are done in per-frame mode.
#
# # Training SOMA For Ablative Study
# Now we get to training a model for our experiment.
# Some experiments can share data with the normal HDM05 model because only the model settings are being changed;
# i.e. turning off the Transformer model, or using Log-Softmax
# instead of the Sinkhorn normalization.
# However, some need a new round of data preparation because training data components are being experimented with;
# i.e. training stability analysis, no amass marker noise, no CAESAR beta parameters during training.
#
# As mentioned before, due to licensing restrictions we cannot release AMASS marker noise model and CAESAR beta parameters.
# However, we can still run the training with these data. Later we will use the pre-trained models.
#
# As an example let's turn off the transformer elements in the model architecture
# and replace them with 1D convolutions.

# %%
from soma.train.train_soma_multiple import train_multiple_soma

soma_expr_id = 'V48_02_HDM05'

soma_data_settings = [(5, 3, 0.0, 1.0)]

num_gpus = 1
num_cpus = 4

# %%
train_multiple_soma(
    soma_data_settings=soma_data_settings,

    soma_train_cfg = {

        'soma.expr_id': f'{soma_expr_id}_TransformerOFF',

        'data_parms.mocap_dataset.marker_layout_fnames': [hdm05_marker_layout_fname],
        'train_parms.batch_size': 256,
        'train_parms.num_workers': num_cpus,

        'model_parms.labeler.enable_transformer': False,
        'dirs.body_dataset_dir': osp.join(support_base_dir, 'smplx/body_dataset'),

        'dirs.support_base_dir': support_base_dir,
        'dirs.work_base_dir': soma_work_base_dir,
        'data_parms.mocap_dataset.amass_marker_noise_model.enable': False, # not released

        'trainer.distributed_backend': 'dp', # in jupyter you cannot use ddp which is the fastest option
        'trainer.num_gpus': num_gpus,
        'trainer.fast_dev_run': True, #comment for full training

        # 'dirs.marker_dataset_dir': '${dirs.work_base_dir}/data/V48_01_HDM05/marker_dataset',
        # 'dirs.amass_marker_noise_dir': '${dirs.work_base_dir}/data/V48_01_HDM05/amass_marker_noise',

    }
)
# Out:
# Global seed set to 100
# soma_data_module:__init__:87 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Setting up SOMA data loader
# edit_tools:merge_marker_layouts:228 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Merging #1 marker layouts: ['/home/nghorbani/Desktop/SOMA_Test/support_files/marker_layouts/HDM05/dg/HDM_dg_01-04_01_120_smplx_finetuned.json'].
# soma_data_module:prepare_training_superset:76 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Created superset at: /home/nghorbani/Desktop/SOMA_Test/data/V48_02_HDM05_TransformerOFF/marker_dataset/superset.json
# soma_data_module:__init__:110 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Created /home/nghorbani/Desktop/SOMA_Test/data/V48_02_HDM05_TransformerOFF/marker_dataset/superset.ply
# soma_data_module:__init__:126 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- num_points (43) = num_ghost_max (3) * num_body_parts (1) + num_prop_marker_max (0) + num_superset_labels (40)
# synthetic_body_dataset:prepare_synthetic_body_dataset:107 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Synthetic body dataset already exists at /home/nghorbani/Desktop/SOMA_Test/support_files/smplx/body_dataset
# marker_dataset:prepare_marker_dataset:328 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Creating marker dataset with superset /home/nghorbani/Desktop/SOMA_Test/data/V48_02_HDM05_TransformerOFF/marker_dataset/superset.json which has 40 markers.
# marker_dataset:prepare_marker_dataset:329 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Superset marker type distance {'body': 0.0095} meters.
# marker_dataset:prepare_marker_dataset:331 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Will place markers randomly on 1 ring neighbourhood of a vid.
# marker_dataset:prepare_marker_dataset:343 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Preparing data files for split train
# marker_dataset:prepare_marker_dataset:347 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Preparing synthetic marker data for split train from #1043609 body parameters corresponding to datasets ['CMU', 'Transitions', 'PosePrior']
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32613/32613 [07:33<00:00, 71.90it/s]
# marker_dataset:run:270 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- synthetic data: {'root_orient': (1043609, 1, 3), 'betas': (1043609, 1, 10), 'pose_body': (1043609, 1, 63), 'trans': (1043609, 1, 3), 'markers': (1043609, 1, 120), 'data_is_real': (1043609,)}
# marker_dataset:prepare_marker_dataset:358 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- #1043609 synthetic data points created
# marker_dataset:prepare_marker_dataset:389 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Not using real data for split train since use_real_data_for (None) does not have this split name
# marker_dataset:drop_dict_as_pt:82 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Dumped 1043609 data points as pytorch pt files at: /home/nghorbani/Desktop/SOMA_Test/data/V48_02_HDM05_TransformerOFF/marker_dataset/train
# marker_dataset:prepare_marker_dataset:343 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Preparing data files for split vald
# marker_dataset:prepare_marker_dataset:347 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Preparing synthetic marker data for split vald from #137483 body parameters corresponding to datasets ['HumanEva', 'ACCAD', 'TotalCapture']
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4297/4297 [00:59<00:00, 72.57it/s]
# marker_dataset:run:270 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- synthetic data: {'root_orient': (137483, 1, 3), 'betas': (137483, 1, 10), 'pose_body': (137483, 1, 63), 'trans': (137483, 1, 3), 'markers': (137483, 1, 120), 'data_is_real': (137483,)}
# marker_dataset:prepare_marker_dataset:358 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- #137483 synthetic data points created
# marker_dataset:prepare_marker_dataset:389 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Not using real data for split vald since use_real_data_for (None) does not have this split name
# marker_dataset:drop_dict_as_pt:82 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Dumped 137483 data points as pytorch pt files at: /home/nghorbani/Desktop/SOMA_Test/data/V48_02_HDM05_TransformerOFF/marker_dataset/vald
# marker_dataset:prepare_marker_dataset:426 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- marker_dataset_dir: /home/nghorbani/Desktop/SOMA_Test/data/V48_02_HDM05_TransformerOFF/marker_dataset
# mocap_dataset:__init__:77 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Will produce augmented mocap point cloud data for split vald: num_ghost_max = 3, num_occ_max = 5, num_btraj_max = 0, marker_noise_var = 0.00e+00, use_model_based_marker_pos_noise = False
# mocap_dataset:__init__:87 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- split_name = vald, limit_real_data = 0.0, limit_synt_data = 1.0
# mocap_dataset:__init__:105 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- dimensions of loaded data: {'root_orient': torch.Size([137483, 1, 3]), 'betas': torch.Size([137483, 1, 10]), 'pose_body': torch.Size([137483, 1, 63]), 'markers': torch.Size([137483, 1, 120]), 'data_is_real': torch.Size([137483]), 'trans': torch.Size([137483, 1, 3])}
# mocap_dataset:__init__:113 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- loaded dataset settings from ['/home/nghorbani/Desktop/SOMA_Test/data/V48_02_HDM05_TransformerOFF/marker_dataset/vald/../settings.yaml']
# mocap_dataset:__init__:122 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Split vald: Loaded #137483 data points from marker_dataset_dir /home/nghorbani/Desktop/SOMA_Test/data/V48_02_HDM05_TransformerOFF/marker_dataset/vald.
# mocap_dataset:__init__:124 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Split vald: #0 (0.00) real and #137483 (1.00) synthetic data points.
# mocap_dataset:__init__:131 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- synthetic_body_amass_splits: ['HumanEva', 'ACCAD', 'TotalCapture']
# mocap_dataset:__init__:152 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Loading marker layout: /home/nghorbani/Desktop/SOMA_Test/support_files/marker_layouts/HDM05/dg/HDM_dg_01-04_01_120_smplx_finetuned.json
# mocap_dataset:__init__:77 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Will produce augmented mocap point cloud data for split train: num_ghost_max = 3, num_occ_max = 5, num_btraj_max = 0, marker_noise_var = 0.00e+00, use_model_based_marker_pos_noise = False
# mocap_dataset:__init__:87 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- split_name = train, limit_real_data = 0.0, limit_synt_data = 1.0
# mocap_dataset:__init__:96 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Chosen 0.00 of real data point #0 of #0
# mocap_dataset:__init__:105 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- dimensions of loaded data: {'root_orient': torch.Size([1043609, 1, 3]), 'betas': torch.Size([1043609, 1, 10]), 'pose_body': torch.Size([1043609, 1, 63]), 'markers': torch.Size([1043609, 1, 120]), 'data_is_real': torch.Size([1043609]), 'trans': torch.Size([1043609, 1, 3])}
# mocap_dataset:__init__:113 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- loaded dataset settings from ['/home/nghorbani/Desktop/SOMA_Test/data/V48_02_HDM05_TransformerOFF/marker_dataset/train/../settings.yaml']
# mocap_dataset:__init__:122 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Split train: Loaded #1043609 data points from marker_dataset_dir /home/nghorbani/Desktop/SOMA_Test/data/V48_02_HDM05_TransformerOFF/marker_dataset/train.
# mocap_dataset:__init__:124 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Split train: #0 (0.00) real and #1043609 (1.00) synthetic data points.
# mocap_dataset:__init__:131 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- synthetic_body_amass_splits: ['CMU', 'Transitions', 'PosePrior']
# mocap_dataset:__init__:152 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Loading marker layout: /home/nghorbani/Desktop/SOMA_Test/support_files/marker_layouts/HDM05/dg/HDM_dg_01-04_01_120_smplx_finetuned.json
# soma_trainer:__init__:84 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- superset_fname: /home/nghorbani/Desktop/SOMA_Test/data/V48_02_HDM05_TransformerOFF/marker_dataset/superset.json
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Running in fast_dev_run mode: will run a full train, val, test and prediction loop using 1 batch(es).
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/pytorch_lightning/core/datamodule.py:424: LightningDeprecationWarning: DataModule.setup has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.setup.
#   f"DataModule.{name} has already been called, so it will not be called again. "
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name       | Type | Params
# ------------------------------------
# 0 | soma_model | SOMA | 2.1 M
# ------------------------------------
# 2.1 M     Trainable params
# 0         Non-trainable params
# 2.1 M     Total params
# 8.405     Total estimated model params size (MB)
# soma_trainer:configure_optimizers:144 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Total trainable gen_params: 2.1014 M.
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/pytorch_lightning/trainer/data_loading.py:327: UserWarning: The number of training samples (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   f"The number of training samples ({self.num_training_batches}) is smaller than the logging interval"
# Training:   0%|                                                                                                                                                                                                                                                                                                | 0/2 [00:00<00:00, 9892.23it/s]soma_trainer:on_train_start:124 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Created a git archive backup at /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/code/soma_2021_10_09_20_00_13.tar.gz
# Epoch 0:  50%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                                             | 1/2 [00:01<00:00,  1.91it/s, loss=472, v_num=, train_loss_step=472.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|                                                                                                                                                                                                                                                                                                        | 0/1 [00:00<?, ?it/s]
# Validating: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.31it/s]soma_trainer:validation_epoch_end:253 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Epoch 0: val_loss:472.74, f1:0.00, acc:0.02
# soma_trainer:validation_epoch_end:255 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- lr is ['1.00e-03']
# Epoch 0: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:02<00:00,  1.32it/s, loss=472, v_num=, train_loss_step=472.0, val_loss=473.0, val_f1=0.00115, val_acc=0.0241]
# Epoch 0: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:02<00:00,  1.31it/s, loss=472, v_num=, train_loss_step=472.0, val_loss=473.0, val_f1=0.00115, val_acc=0.0241]
# soma_trainer:on_train_end:271 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- best_model_fname:
# soma_trainer:on_train_end:274 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- Epoch 0 - Finished training at 2021_10_09_20_00_16 after 0:00:03

# %% [markdown]
# The above training lasted one epoch and can be turned into a real training  if you comment the line with
# ```` 'trainer.fast_dev_run': True ````.
#
# Instead, grab, not [grab](https://grab.is.tue.mpg.de/), the
# [pre-trained *V48_02_HDM05_TransformerOFF*](https://download.is.tue.mpg.de/download.php?domain=soma&sfile=training_experiments/V48_02_HDM05_TransformerOFF.tar.bz2)
# and place it under *training_experiments* replacing the existing *V48_02_HDM05_TransformerOFF* folder.
# Also download the [corresponding data](https://download.is.tue.mpg.de/download.php?domain=soma&sfile=smplx/data/V48_01_HDM05.tar.bz2) and place it under
# ```` data/ ````.
#
#
# ## Running the Evaluation Code
# With training out of the way let run the SOMA model on the newly corrupted mocaps.

# %%
from soma.tools.run_soma_multiple import run_soma_on_multiple_settings

soma_mocap_target_ds_names = [
    'HDM05___HDM05___OC_05_G_03_BT_00', # without broken trajectories for a per-frame validation
]
soma_data_ids = [
    'OC_05_G_03_real_000_synt_100',
]
soma_expr_ids = [f'{soma_expr_id}_TransformerOFF']

soma_cfg={
    'soma.batch_size': 256,
    'mocap.unit': 'm',
    'save_c3d': True,
    'keep_nan_points': True,  # required for labeling evaluation
    'remove_zero_trajectories': False,  # required for labeling
    'dirs.support_base_dir': support_base_dir,
}

# %%
run_soma_on_multiple_settings(soma_expr_ids=soma_expr_ids,
                              soma_mocap_target_ds_names=soma_mocap_target_ds_names,
                              soma_data_ids=soma_data_ids,
                              tracklet_labeling_options=[False],  # always per frame in this experiment
                              soma_cfg=soma_cfg,
                              parallel_cfg={
                                    'max_num_jobs': 10,
                                    'randomly_run_jobs': True,
                                },
                              run_tasks=['soma'],
                              fname_filter=None,
                              # fast_dev_run=True,
                              mocap_ext='.pkl',
                              soma_work_base_dir=soma_work_base_dir,
                              mocap_base_dir=mocap_out_base_dir)
# Out:
# run_soma_multiple:run_soma_on_multiple_settings:245 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- Submitting SOMA jobs.
# parallel_tools:run_parallel_jobs:54 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- #Job(s) submitted: 215
# parallel_tools:run_parallel_jobs:58 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- max_num_jobs is set to 10. choosing the first #Job(s): 10
# parallel_tools:run_parallel_jobs:67 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- Will run the jobs in random order.
# soma_processor:__init__:98 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-03_03_120 -- Starting SOMA on /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_01-03_03_120.pkl
# model_loader:load_model:91 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-03_03_120 -- Loaded model in eval mode with trained weights: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/snapshots/V48_02_HDM05_TransformerOFF_epoch=16_val_f1=0.12_val_acc=0.11.ckpt
# soma_processor:__init__:148 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-03_03_120 -- loaded mocap points. #markers.shape = (3674, 43, 3), frame_rate: 120.0 and available points 93.22%
# soma_processor:__init__:150 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-03_03_120 -- Maximum number of non-zero points per-frame: 43
# soma_processor:__init__:159 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-03_03_120 -- SOMA is trained for #40 markers of layout: /home/nghorbani/Desktop/SOMA_Test/data/V48_01_HDM05/marker_dataset/superset.json
# soma_processor:apply_soma:197 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-03_03_120 -- Applying SOMA on mocap with batch_size = 512
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00,  9.38it/s]
# soma_processor:apply_soma:234 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-03_03_120 -- SOMA was performing at 3674.0 Hz.
# soma_processor:label_perframe:337 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-03_03_120 -- 82 labels detected
# soma_processor:label_perframe:341 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-03_03_120 -- Per-frame labeling yielded 48.88% non-zero mocap.
# soma_processor:run_soma_once:446 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-03_03_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_01-03_03_120.pkl
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/moshpp-3.0-py3.7.egg/moshpp/tools/c3d.py:902: UserWarning: missing parameter ANALOG:LABELS
#   warnings.warn('missing parameter {}'.format(name))
# /is/ps3/nghorbani/opt/anaconda3/envs/soma-public/lib/python3.7/site-packages/moshpp-3.0-py3.7.egg/moshpp/tools/c3d.py:902: UserWarning: missing parameter ANALOG:DESCRIPTIONS
#   warnings.warn('missing parameter {}'.format(name))
# soma_processor:run_soma_once:455 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-03_03_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_01-03_03_120.c3d
# soma_processor:run_soma_once:457 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-03_03_120 -- ----------------
# soma_processor:__init__:98 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_03_120 -- Starting SOMA on /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-02_03_120.pkl
# model_loader:load_model:91 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_03_120 -- Loaded model in eval mode with trained weights: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/snapshots/V48_02_HDM05_TransformerOFF_epoch=16_val_f1=0.12_val_acc=0.11.ckpt
# soma_processor:__init__:148 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_03_120 -- loaded mocap points. #markers.shape = (4237, 43, 3), frame_rate: 120.0 and available points 93.29%
# soma_processor:__init__:150 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_03_120 -- Maximum number of non-zero points per-frame: 43
# soma_processor:__init__:159 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_03_120 -- SOMA is trained for #40 markers of layout: /home/nghorbani/Desktop/SOMA_Test/data/V48_01_HDM05/marker_dataset/superset.json
# soma_processor:apply_soma:197 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_03_120 -- Applying SOMA on mocap with batch_size = 512
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 10.84it/s]
# soma_processor:apply_soma:234 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_03_120 -- SOMA was performing at 4237.0 Hz.
# soma_processor:label_perframe:337 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_03_120 -- 82 labels detected
# soma_processor:label_perframe:341 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_03_120 -- Per-frame labeling yielded 48.92% non-zero mocap.
# soma_processor:run_soma_once:446 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_03_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-02_03_120.pkl
# soma_processor:run_soma_once:455 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_03_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-02_03_120.c3d
# soma_processor:run_soma_once:457 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_03_120 -- ----------------
# soma_processor:__init__:98 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- Starting SOMA on /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-02_02_120.pkl
# model_loader:load_model:91 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- Loaded model in eval mode with trained weights: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/snapshots/V48_02_HDM05_TransformerOFF_epoch=16_val_f1=0.12_val_acc=0.11.ckpt
# soma_processor:__init__:148 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- loaded mocap points. #markers.shape = (8500, 43, 3), frame_rate: 120.0 and available points 93.28%
# soma_processor:__init__:150 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- Maximum number of non-zero points per-frame: 43
# soma_processor:__init__:159 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- SOMA is trained for #40 markers of layout: /home/nghorbani/Desktop/SOMA_Test/data/V48_01_HDM05/marker_dataset/superset.json
# soma_processor:apply_soma:197 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- Applying SOMA on mocap with batch_size = 512
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 17/17 [00:01<00:00,  9.32it/s]
# soma_processor:apply_soma:234 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- SOMA was performing at 4250.0 Hz.
# soma_processor:label_perframe:337 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- 83 labels detected
# soma_processor:label_perframe:341 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- Per-frame labeling yielded 48.33% non-zero mocap.
# soma_processor:run_soma_once:446 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-02_02_120.pkl
# soma_processor:run_soma_once:455 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-02_02_120.c3d
# soma_processor:run_soma_once:457 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- ----------------
# soma_processor:__init__:98 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- Starting SOMA on /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_05-03_02_120.pkl
# model_loader:load_model:91 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- Loaded model in eval mode with trained weights: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/snapshots/V48_02_HDM05_TransformerOFF_epoch=16_val_f1=0.12_val_acc=0.11.ckpt
# soma_processor:__init__:148 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- loaded mocap points. #markers.shape = (4167, 43, 3), frame_rate: 120.0 and available points 93.22%
# soma_processor:__init__:150 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- Maximum number of non-zero points per-frame: 43
# soma_processor:__init__:159 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- SOMA is trained for #40 markers of layout: /home/nghorbani/Desktop/SOMA_Test/data/V48_01_HDM05/marker_dataset/superset.json
# soma_processor:apply_soma:197 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- Applying SOMA on mocap with batch_size = 512
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 10.81it/s]
# soma_processor:apply_soma:234 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- SOMA was performing at 4167.0 Hz.
# soma_processor:label_perframe:337 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- 82 labels detected
# soma_processor:label_perframe:341 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- Per-frame labeling yielded 48.89% non-zero mocap.
# soma_processor:run_soma_once:446 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_05-03_02_120.pkl
# soma_processor:run_soma_once:455 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_05-03_02_120.c3d
# soma_processor:run_soma_once:457 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- ----------------
# soma_processor:__init__:98 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-01_03_120 -- Starting SOMA on /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-01_03_120.pkl
# model_loader:load_model:91 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-01_03_120 -- Loaded model in eval mode with trained weights: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/snapshots/V48_02_HDM05_TransformerOFF_epoch=16_val_f1=0.12_val_acc=0.11.ckpt
# soma_processor:__init__:148 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-01_03_120 -- loaded mocap points. #markers.shape = (3576, 43, 3), frame_rate: 120.0 and available points 93.23%
# soma_processor:__init__:150 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-01_03_120 -- Maximum number of non-zero points per-frame: 43
# soma_processor:__init__:159 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-01_03_120 -- SOMA is trained for #40 markers of layout: /home/nghorbani/Desktop/SOMA_Test/data/V48_01_HDM05/marker_dataset/superset.json
# soma_processor:apply_soma:197 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-01_03_120 -- Applying SOMA on mocap with batch_size = 512
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00,  8.70it/s]
# soma_processor:apply_soma:234 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-01_03_120 -- SOMA was performing at 3576.0 Hz.
# soma_processor:label_perframe:337 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-01_03_120 -- 81 labels detected
# soma_processor:label_perframe:341 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-01_03_120 -- Per-frame labeling yielded 49.49% non-zero mocap.
# soma_processor:run_soma_once:446 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-01_03_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-01_03_120.pkl
# soma_processor:run_soma_once:455 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-01_03_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-01_03_120.c3d
# soma_processor:run_soma_once:457 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-01_03_120 -- ----------------
# soma_processor:__init__:98 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- Starting SOMA on /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-05_01_120.pkl
# model_loader:load_model:91 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- Loaded model in eval mode with trained weights: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/snapshots/V48_02_HDM05_TransformerOFF_epoch=16_val_f1=0.12_val_acc=0.11.ckpt
# soma_processor:__init__:148 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- loaded mocap points. #markers.shape = (1994, 43, 3), frame_rate: 120.0 and available points 93.18%
# soma_processor:__init__:150 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- Maximum number of non-zero points per-frame: 43
# soma_processor:__init__:159 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- SOMA is trained for #40 markers of layout: /home/nghorbani/Desktop/SOMA_Test/data/V48_01_HDM05/marker_dataset/superset.json
# soma_processor:apply_soma:197 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- Applying SOMA on mocap with batch_size = 512
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  7.56it/s]
# soma_processor:apply_soma:234 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- SOMA was performing at inf Hz.
# soma_processor:label_perframe:337 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- 82 labels detected
# soma_processor:label_perframe:341 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- Per-frame labeling yielded 48.86% non-zero mocap.
# soma_processor:run_soma_once:446 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-05_01_120.pkl
# soma_processor:run_soma_once:455 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-05_01_120.c3d
# soma_processor:run_soma_once:457 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- ----------------
# soma_processor:__init__:98 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-02_03_120 -- Starting SOMA on /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_05-02_03_120.pkl
# model_loader:load_model:91 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-02_03_120 -- Loaded model in eval mode with trained weights: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/snapshots/V48_02_HDM05_TransformerOFF_epoch=16_val_f1=0.12_val_acc=0.11.ckpt
# soma_processor:__init__:148 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-02_03_120 -- loaded mocap points. #markers.shape = (2556, 43, 3), frame_rate: 120.0 and available points 93.36%
# soma_processor:__init__:150 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-02_03_120 -- Maximum number of non-zero points per-frame: 43
# soma_processor:__init__:159 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-02_03_120 -- SOMA is trained for #40 markers of layout: /home/nghorbani/Desktop/SOMA_Test/data/V48_01_HDM05/marker_dataset/superset.json
# soma_processor:apply_soma:197 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-02_03_120 -- Applying SOMA on mocap with batch_size = 512
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  7.17it/s]
# soma_processor:apply_soma:234 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-02_03_120 -- SOMA was performing at 2556.0 Hz.
# soma_processor:label_perframe:337 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-02_03_120 -- 82 labels detected
# soma_processor:label_perframe:341 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-02_03_120 -- Per-frame labeling yielded 48.96% non-zero mocap.
# soma_processor:run_soma_once:446 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-02_03_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_05-02_03_120.pkl
# soma_processor:run_soma_once:455 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-02_03_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_05-02_03_120.c3d
# soma_processor:run_soma_once:457 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-02_03_120 -- ----------------
# soma_processor:__init__:98 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-02_03_120 -- Starting SOMA on /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_01-02_03_120.pkl
# model_loader:load_model:91 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-02_03_120 -- Loaded model in eval mode with trained weights: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/snapshots/V48_02_HDM05_TransformerOFF_epoch=16_val_f1=0.12_val_acc=0.11.ckpt
# soma_processor:__init__:148 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-02_03_120 -- loaded mocap points. #markers.shape = (3990, 43, 3), frame_rate: 120.0 and available points 93.27%
# soma_processor:__init__:150 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-02_03_120 -- Maximum number of non-zero points per-frame: 43
# soma_processor:__init__:159 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-02_03_120 -- SOMA is trained for #40 markers of layout: /home/nghorbani/Desktop/SOMA_Test/data/V48_01_HDM05/marker_dataset/superset.json
# soma_processor:apply_soma:197 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-02_03_120 -- Applying SOMA on mocap with batch_size = 512
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 10.03it/s]
# soma_processor:apply_soma:234 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-02_03_120 -- SOMA was performing at inf Hz.
# soma_processor:label_perframe:337 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-02_03_120 -- 82 labels detected
# soma_processor:label_perframe:341 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-02_03_120 -- Per-frame labeling yielded 48.91% non-zero mocap.
# soma_processor:run_soma_once:446 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-02_03_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_01-02_03_120.pkl
# soma_processor:run_soma_once:455 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-02_03_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_01-02_03_120.c3d
# soma_processor:run_soma_once:457 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_01-02_03_120 -- ----------------
# soma_processor:__init__:98 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_04-01_02_120 -- Starting SOMA on /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_04-01_02_120.pkl
# model_loader:load_model:91 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_04-01_02_120 -- Loaded model in eval mode with trained weights: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/snapshots/V48_02_HDM05_TransformerOFF_epoch=16_val_f1=0.12_val_acc=0.11.ckpt
# soma_processor:__init__:148 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_04-01_02_120 -- loaded mocap points. #markers.shape = (7535, 43, 3), frame_rate: 120.0 and available points 93.33%
# soma_processor:__init__:150 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_04-01_02_120 -- Maximum number of non-zero points per-frame: 43
# soma_processor:__init__:159 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_04-01_02_120 -- SOMA is trained for #40 markers of layout: /home/nghorbani/Desktop/SOMA_Test/data/V48_01_HDM05/marker_dataset/superset.json
# soma_processor:apply_soma:197 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_04-01_02_120 -- Applying SOMA on mocap with batch_size = 512
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:01<00:00,  9.71it/s]
# soma_processor:apply_soma:234 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_04-01_02_120 -- SOMA was performing at 7535.0 Hz.
# soma_processor:label_perframe:337 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_04-01_02_120 -- 83 labels detected
# soma_processor:label_perframe:341 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_04-01_02_120 -- Per-frame labeling yielded 48.35% non-zero mocap.
# soma_processor:run_soma_once:446 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_04-01_02_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_04-01_02_120.pkl
# soma_processor:run_soma_once:455 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_04-01_02_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_04-01_02_120.c3d
# soma_processor:run_soma_once:457 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_04-01_02_120 -- ----------------
# soma_processor:__init__:98 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- Starting SOMA on /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-02_01_120.pkl
# model_loader:load_model:91 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- Loaded model in eval mode with trained weights: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/snapshots/V48_02_HDM05_TransformerOFF_epoch=16_val_f1=0.12_val_acc=0.11.ckpt
# soma_processor:__init__:148 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- loaded mocap points. #markers.shape = (7671, 43, 3), frame_rate: 120.0 and available points 93.23%
# soma_processor:__init__:150 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- Maximum number of non-zero points per-frame: 43
# soma_processor:__init__:159 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- SOMA is trained for #40 markers of layout: /home/nghorbani/Desktop/SOMA_Test/data/V48_01_HDM05/marker_dataset/superset.json
# soma_processor:apply_soma:197 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- Applying SOMA on mocap with batch_size = 512
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:01<00:00, 10.18it/s]
# soma_processor:apply_soma:234 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- SOMA was performing at 7671.0 Hz.
# soma_processor:label_perframe:337 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- 83 labels detected
# soma_processor:label_perframe:341 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- Per-frame labeling yielded 48.30% non-zero mocap.
# soma_processor:run_soma_once:446 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-02_01_120.pkl
# soma_processor:run_soma_once:455 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- Created /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-02_01_120.c3d
# soma_processor:run_soma_once:457 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- ----------------

# %% [markdown]
# As we have set the _max_num_jobs_ to 10, the SOMA processor labeled only 10 sequences. You can either comment this line to process every mocap or continue for now with only 10.
# Let's see how the labeling performance of this model was.

# %%
run_soma_on_multiple_settings(soma_expr_ids=soma_expr_ids,
                              soma_mocap_target_ds_names=soma_mocap_target_ds_names,
                              soma_data_ids=soma_data_ids,
                              tracklet_labeling_options=[False],  # always per frame in this experiment
                              soma_cfg=soma_cfg,
                              parallel_cfg={
                                    'max_num_jobs': 10,
                                    'randomly_run_jobs': True,
                                },
                              run_tasks=['eval_label'],
                              fname_filter=None,
                              # fast_dev_run=True,
                              mocap_ext='.pkl',
                              soma_work_base_dir=soma_work_base_dir,
                              mocap_base_dir=mocap_out_base_dir)
# Out:
# run_soma_multiple:run_soma_on_multiple_settings:267 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- Submitting SOMA label evaluations jobs.
# parallel_tools:run_parallel_jobs:54 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- #Job(s) submitted: 10
# parallel_tools:run_parallel_jobs:58 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- max_num_jobs is set to 10. choosing the first #Job(s): 10
# parallel_tools:run_parallel_jobs:67 -- V48_02_HDM05_TransformerOFF -- OC_05_G_03_real_000_synt_100 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- Will run the jobs in random order.
# eval_labeling:evaluate_labeling_once:81 -- Beginning to evaluate labeling performance.
# eval_labeling:evaluate_labeling_once:82 -- mocap_rec: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-02_01_120.pkl
# eval_labeling:evaluate_labeling_once:83 -- mocap_gt: /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-02_01_120.pkl
# eval_labeling:evaluate_labeling_once:180 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-02_01_120 -- acc=9.39, f1=8.40, prec=16.68, recall=7.45
# eval_labeling:evaluate_labeling_once:188 -- created: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_eval/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-02_01_120_labeling.pkl
# eval_labeling:evaluate_labeling_once:196 -- created: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_eval/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-02_01_120_labeling.xlsx
# eval_labeling:evaluate_labeling_once:81 -- Beginning to evaluate labeling performance.
# eval_labeling:evaluate_labeling_once:82 -- mocap_rec: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-05_01_120.pkl
# eval_labeling:evaluate_labeling_once:83 -- mocap_gt: /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-05_01_120.pkl
# eval_labeling:evaluate_labeling_once:180 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_03-05_01_120 -- acc=8.11, f1=6.99, prec=15.72, recall=6.19
# eval_labeling:evaluate_labeling_once:188 -- created: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_eval/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-05_01_120_labeling.pkl
# eval_labeling:evaluate_labeling_once:196 -- created: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_eval/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_03-05_01_120_labeling.xlsx
# eval_labeling:evaluate_labeling_once:81 -- Beginning to evaluate labeling performance.
# eval_labeling:evaluate_labeling_once:82 -- mocap_rec: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_05-02_03_120.pkl
# eval_labeling:evaluate_labeling_once:83 -- mocap_gt: /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_05-02_03_120.pkl
# eval_tools:find_corresponding_labels:83 -- Frame 0: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 1: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 3: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 4: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 5: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 6: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 7: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 8: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 9: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 10: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 11: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 12: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 13: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 16: There exists overlapping soma-to-gt assignment: 39 vs. possible 37
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 17: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 18: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 19: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 20: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 21: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 22: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 23: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 24: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 25: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 27: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 28: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 29: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 30: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 31: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 33: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 34: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 35: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 36: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 37: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 38: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 40: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 41: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 42: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 43: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 44: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 45: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 46: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 47: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 48: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 49: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 50: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 51: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 53: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 54: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 55: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 56: There exists overlapping soma-to-gt assignment: 39 vs. possible 37
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 57: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 58: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 59: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 60: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 61: There exists overlapping soma-to-gt assignment: 39 vs. possible 37
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 62: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 63: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 64: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 65: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 67: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 68: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 69: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 70: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 71: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 72: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 73: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 74: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 75: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 76: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 77: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 78: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 79: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 80: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 81: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 82: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 83: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 84: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 85: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 86: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 87: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 88: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 89: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 90: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 91: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 92: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 93: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 94: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 95: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 96: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 98: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 99: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 100: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 101: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 104: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 105: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 106: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 107: There exists overlapping soma-to-gt assignment: 39 vs. possible 37
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 108: There exists overlapping soma-to-gt assignment: 39 vs. possible 37
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 109: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 110: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 111: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 112: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 114: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 115: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 116: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 118: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 119: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 120: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 121: There exists overlapping soma-to-gt assignment: 39 vs. possible 37
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 122: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 123: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 124: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 128: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 129: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 130: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 131: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 132: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 133: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 134: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 135: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 136: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 137: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 138: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 139: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 140: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 141: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 142: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 143: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 145: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 146: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 147: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 148: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 149: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 151: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 153: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 154: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 155: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 156: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 157: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 159: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 160: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 161: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 162: There exists overlapping soma-to-gt assignment: 39 vs. possible 37
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 163: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 164: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 165: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 166: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 167: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 168: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 169: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 170: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 171: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 172: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 173: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 174: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 175: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 176: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 177: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 178: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 179: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 180: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 181: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 182: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 184: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 185: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 186: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 187: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 188: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 189: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 190: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 191: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 192: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 193: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 194: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 195: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 196: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 197: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 199: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 200: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 201: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 202: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 203: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 205: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 206: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 207: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 208: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 209: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 210: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 211: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 213: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 214: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 216: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 217: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 218: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 219: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 220: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 221: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 222: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 224: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 225: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 226: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 227: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 228: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 229: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 230: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 231: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 232: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 233: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 234: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 235: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 236: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 237: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 238: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 240: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 241: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 242: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 243: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 244: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 245: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 246: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 247: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 248: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 249: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 250: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 251: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# ...
# eval_tools:find_corresponding_labels:83 -- Frame 2170: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2171: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2172: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2173: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2174: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2175: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2176: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2177: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2178: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2179: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2180: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2181: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2183: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2184: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2185: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2186: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2187: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2188: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2189: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2190: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2191: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2192: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2193: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2194: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2195: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2196: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2198: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2199: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2200: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2201: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2202: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2203: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2204: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2205: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2206: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2207: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2209: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2210: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2211: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2212: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2213: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2214: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2215: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2216: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2217: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2218: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2219: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2220: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2221: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2222: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2224: There exists overlapping soma-to-gt assignment: 39 vs. possible 37
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2225: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2226: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2227: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2228: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2229: There exists overlapping soma-to-gt assignment: 45 vs. possible 43
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2230: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2231: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2232: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2233: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2234: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2237: There exists overlapping soma-to-gt assignment: 40 vs. possible 38
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2238: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2239: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2241: There exists overlapping soma-to-gt assignment: 39 vs. possible 37
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2242: There exists overlapping soma-to-gt assignment: 42 vs. possible 40
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2243: There exists overlapping soma-to-gt assignment: 41 vs. possible 39
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2244: There exists overlapping soma-to-gt assignment: 43 vs. possible 41
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2245: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2246: There exists overlapping soma-to-gt assignment: 39 vs. possible 37
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_tools:find_corresponding_labels:83 -- Frame 2247: There exists overlapping soma-to-gt assignment: 44 vs. possible 42
# eval_tools:find_corresponding_labels:85 -- Try reducing either rtol or atol
# eval_labeling:evaluate_labeling_once:180 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_05-03_02_120 -- acc=11.23, f1=10.41, prec=19.39, recall=9.13
# eval_labeling:evaluate_labeling_once:188 -- created: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_eval/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_05-03_02_120_labeling.pkl
# eval_labeling:evaluate_labeling_once:196 -- created: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_eval/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_05-03_02_120_labeling.xlsx
# eval_labeling:evaluate_labeling_once:81 -- Beginning to evaluate labeling performance.
# eval_labeling:evaluate_labeling_once:82 -- mocap_rec: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-02_02_120.pkl
# eval_labeling:evaluate_labeling_once:83 -- mocap_gt: /home/nghorbani/Desktop/SOMA_Test/support_files/evaluation_mocaps/with_synthetic_noise/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-02_02_120.pkl
# eval_labeling:evaluate_labeling_once:180 -- HDM05___HDM05___OC_05_G_03_BT_00 -- mm -- HDM_mm_02-02_02_120 -- acc=12.23, f1=11.80, prec=22.58, recall=10.23
# eval_labeling:evaluate_labeling_once:188 -- created: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_eval/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-02_02_120_labeling.pkl
# eval_labeling:evaluate_labeling_once:196 -- created: /home/nghorbani/Desktop/SOMA_Test/training_experiments/V48_02_HDM05_TransformerOFF/OC_05_G_03_real_000_synt_100/evaluations/soma_eval/HDM05___HDM05___OC_05_G_03_BT_00/mm/HDM_mm_02-02_02_120_labeling.xlsx

# %% [markdown]
# As expected we observe very bad performance when the Transformer elements are removed from the pipeline. You can run similar experiments on any aspect of the SOMA model, data, and training procedure.
